# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
combine = [train_df, test_df]

# %%
print(train_df.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %%
# preview the data
train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
train_df.describe() #Get summary of numerical variables
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.describe(include=['O']) #Get summary of categorical variables
# Out:
#                              Name   Sex    Ticket        Cabin Embarked
# count                         891   891       891          204      889
# unique                        891     2       681          147        3
# top     Graham, Mr. George Edward  male  CA. 2343  C23 C25 C27        S
# freq                            1   577         7            4      644

# %%
# Analyze by pivoting features
train_df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train_df[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train_df[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train_df[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
# Analyze by visualizing data
g = sns.FacetGrid(train_df, col='Survived')
g.map(plt.hist, 'Age', bins=20)

# %%
grid = sns.FacetGrid(train_df, col='Survived', row='Pclass', size=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20, color="r")
grid.add_legend();

# %%
grid = sns.FacetGrid(train_df, col='Survived', row='Sex', size=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20, color="g")
grid.add_legend();

# %%
grid = sns.FacetGrid(train_df, row='Embarked', size=2.2, aspect=1.6)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette='deep')
grid.add_legend()
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
grid = sns.FacetGrid(train_df, row='Embarked', col='Survived', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha=.5, ci=None, color="darkviolet")
grid.add_legend()
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
# Dropping irrevalent features
print ("Before", train_df.shape, test_df.shape, combine[0].shape, combine[1].shape)

train_df = train_df.drop(['Ticket', 'Cabin'], axis=1)
test_df = test_df.drop(['Ticket', 'Cabin'], axis=1)
combine = [train_df, test_df]

print ("After", train_df.shape, test_df.shape, combine[0].shape, combine[1].shape)
# Out:
# ('Before', (891, 12), (418, 11), (891, 12), (418, 11))
# ('After', (891, 10), (418, 9), (891, 10), (418, 9))

# %%
# Creating new feature
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train_df['Title'], train_df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
# replacing many titles with a more common name or classify them as Rare
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    
train_df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
# converting the categorical titles to ordinal
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch     Fare Embarked  Title
# 0      0   7.2500        S      1
# 1      0  71.2833        C      3
# 2      0   7.9250        S      2
# 3      0  53.1000        S      3
# 4      0   8.0500        S      1
# 5      0   8.4583        Q      1
# 6      0  51.8625        S      1
# 7      1  21.0750        S      4
# 8      2  11.1333        S      3
# 9      0  30.0708        C      3

# %%
# Dropping irrevalent features
train_df = train_df.drop(['Name', 'PassengerId'], axis=1)
test_df = test_df.drop(['Name'], axis=1)
combine = [train_df, test_df]
train_df.shape, test_df.shape
# Out:
# ((891, 9), (418, 9))

# %%
# converting the categorical Sex feature
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

train_df.head(10)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        S      1
# 1         1       1    1  38.0      1      0  71.2833        C      3
# 2         1       3    1  26.0      0      0   7.9250        S      2
# 3         1       1    1  35.0      1      0  53.1000        S      3
# 4         0       3    0  35.0      0      0   8.0500        S      1
# 5         0       3    0   NaN      0      0   8.4583        Q      1
# 6         0       1    0  54.0      0      0  51.8625        S      1
# 7         0       3    0   2.0      3      1  21.0750        S      4
# 8         1       3    1  27.0      0      2  11.1333        S      3
# 9         1       2    1  14.0      1      0  30.0708        C      3

# %%
# looking at missing values in all the variables in training set
train_df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# Title         0
# dtype: int64

# %%
# looking at missing values in all the variables in test set
test_df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# PassengerId     0
# Pclass          0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Fare            1
# Embarked        0
# Title           0
# dtype: int64

# %%
grid = sns.FacetGrid(train_df, row='Pclass', col='Sex', size=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20, color="maroon")
grid.add_legend()

# %%
# an empty array to contain guessed Age values based on Pclass x Gender combinations
guess_ages = np.zeros((2,3))
guess_ages
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %%
# Filling missing values of Age variable
for dataset in combine:
    for i in range(0, 2):
        for j in range(0, 3):
            guess_df = dataset[(dataset['Sex'] == i) & \
                                  (dataset['Pclass'] == j+1)]['Age'].dropna()

            # age_mean = guess_df.mean()
            # age_std = guess_df.std()
            # age_guess = rnd.uniform(age_mean - age_std, age_mean + age_std)

            age_guess = guess_df.median()

            # Convert random age float to nearest .5 age
            guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5
            
    for i in range(0, 2):
        for j in range(0, 3):
            dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),\
                    'Age'] = guess_ages[i,j]

    dataset['Age'] = dataset['Age'].astype(int)

train_df.head(10)
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0   22      1      0   7.2500        S      1
# 1         1       1    1   38      1      0  71.2833        C      3
# 2         1       3    1   26      0      0   7.9250        S      2
# 3         1       1    1   35      1      0  53.1000        S      3
# 4         0       3    0   35      0      0   8.0500        S      1
# 5         0       3    0   25      0      0   8.4583        Q      1
# 6         0       1    0   54      0      0  51.8625        S      1
# 7         0       3    0    2      3      1  21.0750        S      4
# 8         1       3    1   27      0      2  11.1333        S      3
# 9         1       2    1   14      1      0  30.0708        C      3

# %%
# creating Age bands and determine correlations with Survived
train_df['AgeBand'] = pd.cut(train_df['Age'], 5)
train_df[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.550000
# 1   (16.0, 32.0]  0.337374
# 2   (32.0, 48.0]  0.412037
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %%
# replacing Age with ordinals based on these bands
for dataset in combine:    
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age']
train_df.head(10)
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title  \
# 0         0       3    0    1      1      0   7.2500        S      1
# 1         1       1    1    2      1      0  71.2833        C      3
# 2         1       3    1    1      0      0   7.9250        S      2
# 3         1       1    1    2      1      0  53.1000        S      3
# 4         0       3    0    2      0      0   8.0500        S      1
# 5         0       3    0    1      0      0   8.4583        Q      1
# 6         0       1    0    3      0      0  51.8625        S      1
# 7         0       3    0    0      3      1  21.0750        S      4
# 8         1       3    1    1      0      2  11.1333        S      3
# 9         1       2    1    0      1      0  30.0708        C      3
#
#          AgeBand
# 0   (16.0, 32.0]
# 1   (32.0, 48.0]
# 2   (16.0, 32.0]
# 3   (32.0, 48.0]
# 4   (32.0, 48.0]
# 5   (16.0, 32.0]
# 6   (48.0, 64.0]
# 7  (-0.08, 16.0]
# 8   (16.0, 32.0]
# 9  (-0.08, 16.0]

# %%
# dropping AgeBand feature
train_df = train_df.drop(['AgeBand'], axis=1)
combine = [train_df, test_df]
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0    1      1      0   7.2500        S      1
# 1         1       1    1    2      1      0  71.2833        C      3
# 2         1       3    1    1      0      0   7.9250        S      2
# 3         1       1    1    2      1      0  53.1000        S      3
# 4         0       3    0    2      0      0   8.0500        S      1

# %%
# creating a new feature for FamilySize which combines Parch and SibSp
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

train_df[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
# creating another feature called IsAlone
for dataset in combine:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1

train_df[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean()
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
# dropping Parch, SibSp, and FamilySize features in favor of IsAlone
train_df = train_df.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
test_df = test_df.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
combine = [train_df, test_df]

train_df.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare Embarked  Title  IsAlone
# 0         0       3    0    1   7.2500        S      1        0
# 1         1       1    1    2  71.2833        C      3        0
# 2         1       3    1    1   7.9250        S      2        1
# 3         1       1    1    2  53.1000        S      3        0
# 4         0       3    0    2   8.0500        S      1        1

# %%
# creating an artificial feature combining Pclass and Age
for dataset in combine:
    dataset['Age*Class'] = dataset.Age * dataset.Pclass

train_df.loc[:, ['Age*Class', 'Age', 'Pclass']].head(10)
# Out:
#    Age*Class  Age  Pclass
# 0          3    1       3
# 1          2    2       1
# 2          3    1       3
# 3          2    2       1
# 4          6    2       3
# 5          3    1       3
# 6          3    3       1
# 7          0    0       3
# 8          3    1       3
# 9          0    0       2

# %%
freq_port = train_df.Embarked.dropna().mode()[0]
freq_port
# Out:
# 'S'

# %%
# Filling missing values of Embarked variable
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)
    
train_df[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %%
# Converting categorical feature Embarked to numeric
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

train_df.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1   7.2500         0      1        0          3
# 1         1       1    1    2  71.2833         1      3        0          2
# 2         1       3    1    1   7.9250         0      2        1          3
# 3         1       1    1    2  53.1000         0      3        0          2
# 4         0       3    0    2   8.0500         0      1        1          6

# %%
# Filling missing values of Fare variable
test_df['Fare'].fillna(test_df['Fare'].dropna().median(), inplace=True)
test_df.head()
# Out:
#    PassengerId  Pclass  Sex  Age     Fare  Embarked  Title  IsAlone  Age*Class
# 0          892       3    0    2   7.8292         2      1        1          6
# 1          893       3    1    2   7.0000         0      3        0          6
# 2          894       2    0    3   9.6875         2      1        1          6
# 3          895       3    0    1   8.6625         0      1        1          3
# 4          896       3    1    1  12.2875         0      3        0          3

# %%
# Creating FareBand
train_df['FareBand'] = pd.qcut(train_df['Fare'], 4)
train_df[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=True)
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
# Converting the Fare feature to ordinal values based on the FareBand
for dataset in combine:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

train_df = train_df.drop(['FareBand'], axis=1)
combine = [train_df, test_df]
    
train_df.head(10)
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1     0         0      1        0          3
# 1         1       1    1    2     3         1      3        0          2
# 2         1       3    1    1     1         0      2        1          3
# 3         1       1    1    2     3         0      3        0          2
# 4         0       3    0    2     1         0      1        1          6
# 5         0       3    0    1     1         2      1        1          3
# 6         0       1    0    3     3         0      1        1          3
# 7         0       3    0    0     2         0      4        0          0
# 8         1       3    1    1     1         0      3        0          3
# 9         1       2    1    0     2         1      3        0          0

# %%
test_df.head(10)
# Out:
#    PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0          892       3    0    2     0         2      1        1          6
# 1          893       3    1    2     0         0      3        0          6
# 2          894       2    0    3     1         2      1        1          6
# 3          895       3    0    1     1         0      1        1          3
# 4          896       3    1    1     1         0      3        0          3
# 5          897       3    0    0     1         0      1        1          0
# 6          898       3    1    1     0         2      2        1          3
# 7          899       2    0    1     2         0      1        0          2
# 8          900       3    1    1     0         1      3        1          3
# 9          901       3    0    1     2         0      1        0          3

# %%
test_df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# Fare           0
# Embarked       0
# Title          0
# IsAlone        0
# Age*Class      0
# dtype: int64

# %%
X_train = train_df.drop("Survived", axis=1)
Y_train = train_df["Survived"]
X_test  = test_df.drop("PassengerId", axis=1).copy()
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((891, 8), (891,), (418, 8))

# %%
# Logistic Regression

logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train, Y_train) * 100, 2)
acc_log
# Out:
# 80.36

# %%
# calculating the coefficient of the features
coeff_df = pd.DataFrame(train_df.columns.delete(0))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#      Feature  Correlation
# 1        Sex     2.201527
# 5      Title     0.398234
# 2        Age     0.287165
# 4   Embarked     0.261762
# 6    IsAlone     0.129140
# 3       Fare    -0.085150
# 7  Age*Class    -0.311199
# 0     Pclass    -0.749006

# %%
# Support Vector Machines

svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc
# Out:
# 83.84

# %%
# k-Nearest Neighbors
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn
# Out:
# 84.74

# %%
# Gaussian Naive Bayes

gaussian = GaussianNB()
gaussian.fit(X_train, Y_train)
Y_pred = gaussian.predict(X_test)
acc_gaussian = round(gaussian.score(X_train, Y_train) * 100, 2)
acc_gaussian
# Out:
# 72.28

# %%
# Perceptron

perceptron = Perceptron()
perceptron.fit(X_train, Y_train)
Y_pred = perceptron.predict(X_test)
acc_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)
acc_perceptron
# Out:
# 78.0

# %%
# Linear SVC

linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
Y_pred = linear_svc.predict(X_test)
acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
acc_linear_svc
# Out:
# 79.01

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier()
sgd.fit(X_train, Y_train)
Y_pred = sgd.predict(X_test)
acc_sgd = round(sgd.score(X_train, Y_train) * 100, 2)
acc_sgd
# Out:
# 73.74

# %%
# xgboost
gbm = xgb.XGBClassifier(max_depth=15, n_estimators=800, learning_rate=0.05)
gbm.fit(X_train, Y_train)
Y_pred = gbm.predict(X_test)
gbm.score(X_train, Y_train)
acc_gbm = round(gbm.score(X_train, Y_train) * 100, 2)
acc_gbm
# Out:
# 86.53

# %%
# Decision Tree

decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree
# Out:
# 86.76

# %%
# Random Forest

random_forest = RandomForestClassifier(n_estimators=100, max_depth=30, max_features=6, bootstrap=True)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
acc_random_forest
# Out:
# 86.76

# %%
# Tuning of parameters
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [15, 25, 30, 40],
    'max_features': [4, 6, 8],
    'n_estimators': [50, 100, 200]
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)
# Fit the grid search to the data
grid_search.fit(X_train, Y_train)
grid_search.best_params_
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=15, total=   0.6s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=15, total=   0.6s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=15, total=   0.6s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=15, total=   0.6s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=15, total=   0.5s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=15, total=   0.9s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=15, total=   0.8s
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=15, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=15, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=15, total=   1.0s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=15, total=   1.8s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=15, total=   1.9s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=15, total=   0.6s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=15, total=   1.8s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=15, total=   1.9s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=15, total=   0.4s
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=15, total=   0.4s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=15, total=   0.5s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=15, total=   0.5s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=15, total=   2.0s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=15, total=   1.0s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=15, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=15, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=15, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=15, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=15, total=   1.7s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=15, total=   1.7s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=15, total=   1.7s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=15, total=   1.7s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=15, total=   0.4s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=15, total=   0.5s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=15 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=15, total=   0.5s
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=15, total=   0.4s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=15 ..
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   10.2s
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=15, total=   0.5s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=15, total=   1.9s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=15, total=   1.0s
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=15, total=   1.0s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=15 ..
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=15, total=   1.1s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=15, total=   1.0s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=15, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=15, total=   1.8s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=15 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=15, total=   1.8s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=15, total=   1.8s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=25, total=   0.5s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=15, total=   1.8s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=25, total=   0.5s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=25, total=   0.5s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=25, total=   0.4s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=25, total=   0.5s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=15, total=   1.9s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=25, total=   1.8s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=25, total=   1.7s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=25, total=   1.7s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=25, total=   0.5s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=25, total=   0.4s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=25, total=   1.8s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=25, total=   0.5s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=25, total=   0.4s
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=25, total=   0.4s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=25, total=   1.8s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=25, total=   0.8s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=25, total=   1.7s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=25, total=   1.7s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=25, total=   0.4s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=25, total=   1.7s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=25, total=   0.5s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=25, total=   1.8s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=25 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=25, total=   0.5s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=25, total=   0.5s
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=25, total=   0.4s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=25, total=   1.8s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=25 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=25, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=25, total=   1.7s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=25 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=25, total=   1.8s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=25, total=   1.8s
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=30, total=   0.4s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=25, total=   1.8s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=30, total=   0.4s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=30, total=   0.5s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=30, total=   0.4s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=30, total=   0.5s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=25, total=   1.8s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=30, total=   1.7s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=30, total=   1.7s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=30, total=   1.7s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=30, total=   0.4s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=30, total=   1.7s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=30, total=   0.5s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=30, total=   0.4s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=30, total=   0.4s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=30, total=   1.8s
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=30, total=   0.5s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=30, total=   0.8s
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=30, total=   1.8s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=30, total=   1.7s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=30, total=   1.8s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=30, total=   0.5s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=30, total=   1.8s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=30, total=   0.5s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=30 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=30, total=   0.5s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=30, total=   0.5s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=30, total=   0.5s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=30, total=   1.9s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=30, total=   1.0s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=30, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=30, total=   1.7s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=30 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=30, total=   1.7s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=40, total=   0.4s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=30, total=   1.7s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=30, total=   1.8s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=40, total=   0.4s
# [CV] max_features=4, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=40, total=   0.4s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=40, total=   0.5s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=4, n_estimators=50, bootstrap=True, max_depth=40, total=   0.4s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=30, total=   2.0s
# [CV] max_features=4, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=4, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=40, total=   1.7s
# [CV] max_features=4, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=40, total=   1.6s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=40, total=   0.4s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=40, total=   1.7s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=40, total=   1.7s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=40, total=   0.5s
# [CV] max_features=6, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=40, total=   0.5s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=40, total=   0.4s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=50, bootstrap=True, max_depth=40, total=   0.5s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=40 ..
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   47.8s
# [CV]  max_features=4, n_estimators=200, bootstrap=True, max_depth=40, total=   1.9s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=6, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=40, total=   1.7s
# [CV] max_features=6, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=40, total=   1.7s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=40, total=   1.8s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=40, total=   0.4s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=40, total=   1.7s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=40, total=   0.5s
# [CV] max_features=8, n_estimators=50, bootstrap=True, max_depth=40 ...
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=40, total=   0.4s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=40, total=   0.4s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=50, bootstrap=True, max_depth=40, total=   0.5s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=6, n_estimators=200, bootstrap=True, max_depth=40, total=   1.8s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=8, n_estimators=100, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=40, total=   1.0s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=100, bootstrap=True, max_depth=40, total=   0.9s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=40, total=   2.4s
# [CV] max_features=8, n_estimators=200, bootstrap=True, max_depth=40 ..
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=40, total=   2.4s
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=40, total=   2.4s
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=40, total=   2.3s
# [CV]  max_features=8, n_estimators=200, bootstrap=True, max_depth=40, total=   1.3s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   57.2s finished
# {'bootstrap': True, 'max_depth': 15, 'max_features': 6, 'n_estimators': 200}

# %%
# Random Forest with tuned parameters

random_forest = RandomForestClassifier(n_estimators=200, max_depth=15, max_features=6, bootstrap=True)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
acc_random_forest
# Out:
# 86.76

# %%
# Model Evaluation
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent', 'Linear SVC', 
              'Decision Tree','XGBoost'],
    'Score': [acc_svc, acc_knn, acc_log, 
              acc_random_forest, acc_gaussian, acc_perceptron, 
              acc_sgd, acc_linear_svc, acc_decision_tree, acc_gbm]})
models.sort_values(by='Score', ascending=False)
# Out:
#                         Model  Score
# 3               Random Forest  86.76
# 8               Decision Tree  86.76
# 9                     XGBoost  86.53
# 1                         KNN  84.74
# 0     Support Vector Machines  83.84
# 2         Logistic Regression  80.36
# 7                  Linear SVC  79.01
# 5                  Perceptron  78.00
# 6  Stochastic Gradient Decent  73.74
# 4                 Naive Bayes  72.28

# %%
submission = pd.DataFrame({
        "PassengerId": test_df["PassengerId"],
        "Survived": Y_pred
    })

submission.to_csv('submission.csv', index=False)
